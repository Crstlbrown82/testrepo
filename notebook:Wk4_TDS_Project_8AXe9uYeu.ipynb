# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Crystal Muranda** <br>
# Data Analyst

# %% [markdown]
# _I am interested in data science because it fulfills my inquisitive nature. I have always been a results driven person and a problem solver. After learning about data science, I feel it will be fulfuiling to purse it as a career._

# %% [markdown]
# ##### Below, my code is a display of math computational order.

# %%
(5*5)/5*4+3-6
# Out:
# 17.0

# %% [markdown]
# Please ~~remove~~ watch this video.
#
# <a href="https://youtu.be/WRgUu_UCNEg" target="_blank"><img src="http://img.youtube.com/vi/czpPwMB8s3o/0.jpg"
# alt="SALENA WITH REMA" width="240" height="180" border="10" /></a>
